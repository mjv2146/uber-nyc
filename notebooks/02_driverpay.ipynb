# %% [markdown]
# # Driver Pay
# - This notebook studies how rides differ based on their playform
# - Uber has a higher market share of 68% relative to Lyft's market share of 23%
# - I show that Lyft rides are more likely to pay the driver a tip
# - Uber drivers are compensated more per mile or minute, even after accounting for that Lyft riders are more likely to tip

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/uber')
engine.connect()

# %load_ext sql
# %sql postgresql://root:root@localhost:5432/uber

# %%
# %%sql
# SELECT * FROM main
# LIMIT 10;
# Out:
#  * postgresql://root:***@localhost:5432/uber
# 10 rows affected.
# [(19985285, 'HV0005', 'B02510', None, datetime.datetime(2019, 7, 31, 15, 11, 25), None, datetime.datetime(2019, 7, 31, 15, 13, 40), datetime.datetime(2019, 7, 31, 15, 25), 210, 155, 1.653, 680, 10.31, 0.0, 0.19, 0.67, 0.0, None, 0.0, 7.42, 'N', 'N', 'N', 'N', 'N', 15, 'Wednesday', 'Lyft', 0, 4.488808, 0.6547059),
#  (14073898, 'HV0003', 'B02871', 'B02871', datetime.datetime(2019, 7, 22, 18, 27, 36), datetime.datetime(2019, 7, 22, 18, 34, 12), datetime.datetime(2019, 7, 22, 18, 35, 17), datetime.datetime(2019, 7, 22, 18, 46, 59), 61, 35, 1.68, 703, 8.49, 0.0, 0.0, 0.74, 0.0, None, 0.0, 7.63, 'N', 'N', ' ', 'N', 'N', 18, 'Monday', 'Uber', 0, 4.5416665, 0.6512091),
#  (9262571, 'HV0003', 'B02869', 'B02869', datetime.datetime(2019, 7, 15, 23, 24, 7), datetime.datetime(2019, 7, 15, 23, 26, 5), datetime.datetime(2019, 7, 15, 23, 28, 23), datetime.datetime(2019, 7, 15, 23, 50, 20), 35, 139, 9.35, 1316, 23.62, 0.0, 0.0, 2.04, 0.0, None, 0.0, 21.1, 'N', 'N', ' ', 'N', ' ', 23, 'Monday', 'Uber', 0, 2.2566845, 0.9620061),
#  (9004029, 'HV0003', 'B02876', 'B02876', datetime.datetime(2019, 7, 15, 15, 44, 52), datetime.datetime(2019, 7, 15, 15, 45, 45), datetime.datetime(2019, 7, 15, 15, 47, 53), datetime.datetime(2019, 7, 15, 16, 25, 25), 161, 138, 10.03, 2251, 44.94, 6.12, 0.0, 4.42, 2.75, None, 8.73, 44.4, 'N', 'N', ' ', 'N', ' ', 15, 'Monday', 'Uber', 1, 4.4267197, 1.1834741),
#  (674083, 'HV0003', 'B02875', 'B02875', datetime.datetime(2019, 7, 2, 8, 17, 17), datetime.datetime(2019, 7, 2, 8, 24, 33), datetime.datetime(2019, 7, 2, 8, 25, 32), datetime.datetime(2019, 7, 2, 8, 42, 34), 161, 137, 1.7, 1023, -0.75, 0.0, 0.0, 0.0, 0.75, None, 0.0, 6.58, 'Y', 'Y', ' ', 'N', ' ', 8, 'Tuesday', 'Uber', 0, 3.8705883, 0.38592374),
#  (1982460, 'HV0003', 'B02764', 'B02764', datetime.datetime(2019, 7, 4, 14, 41, 58), datetime.datetime(2019, 7, 4, 14, 46, 55), datetime.datetime(2019, 7, 4, 14, 48, 39), datetime.datetime(2019, 7, 4, 15, 1, 16), 205, 215, 2.86, 758, 5.0, 0.0, 0.0, 0.43, 0.0, None, 0.0, 5.93, 'Y', 'Y', ' ', 'N', ' ', 14, 'Thursday', 'Uber', 0, 2.0734265, 0.46939313),
#  (15439192, 'HV0005', 'B02510', None, datetime.datetime(2019, 7, 24, 21, 32, 42), None, datetime.datetime(2019, 7, 24, 21, 34, 31), datetime.datetime(2019, 7, 24, 21, 49, 53), 107, 229, 1.913, 922, 8.73, 0.0, 0.22, 0.77, 0.75, None, 0.0, 0.0, 'Y', 'Y', 'N', 'N', 'N', 21, 'Wednesday', 'Lyft', 0, 0.0, 0.0),
#  (3885337, 'HV0003', 'B02883', 'B02883', datetime.datetime(2019, 7, 7, 17, 40, 31), datetime.datetime(2019, 7, 7, 17, 41, 21), datetime.datetime(2019, 7, 7, 17, 43, 1), datetime.datetime(2019, 7, 7, 18, 7, 33), 68, 138, 9.48, 1472, 38.69, 6.12, 0.0, 3.88, 2.75, None, 0.0, 31.66, 'N', 'N', ' ', 'N', ' ', 17, 'Sunday', 'Uber', 0, 3.3396626, 1.2904891),
#  (4275091, 'HV0003', 'B02764', 'B02764', datetime.datetime(2019, 7, 8, 9, 59, 27), datetime.datetime(2019, 7, 8, 9, 59, 45), datetime.datetime(2019, 7, 8, 10, 1, 8), datetime.datetime(2019, 7, 8, 10, 17, 33), 192, 16, 4.49, 984, 14.45, 0.0, 0.0, 1.25, 0.0, None, 0.0, 13.03, 'N', 'N', ' ', 'N', ' ', 10, 'Monday', 'Uber', 0, 2.9020045, 0.7945122),
#  (18672189, 'HV0004', 'B02800', None, datetime.datetime(2019, 7, 29, 12, 45, 22), None, datetime.datetime(2019, 7, 29, 12, 53, 37), datetime.datetime(2019, 7, 29, 13, 22, 25), 161, 148, 4.2, 1728, 8.75, 0.0, 0.0, 0.78, 0.75, None, 0.0, 0.0, 'Y', 'Y', 'N', 'N', 'N', 12, 'Monday', 'Via', 0, 0.0, 0.0)]

# %% [markdown]
# ### Tips and Ride Platform
# - How does the likelihood of tips vary with the platform?
# - To study this, I group by the TLC license number
# - I first use a subquery to alias the cumbersome 'Hvfhs_license_num' as 'license'
# - I then group by 'license' and use a case statement for brand names
# - I use a descending order of how likely a platform is to have a tip
#
# - We can see that Lyft rides are significantly more likely to tip than Juno, Via, and Uber

# %%
# %%sql
# SELECT
# platform,
# ROUND(100*AVG(
#     (tips > 0)::int
#     ), 2) "Percent with Tips"
# FROM main
# GROUP BY platform
# ORDER BY AVG((tips > 0)::int) DESC
# Out:
#  * postgresql://root:***@localhost:5432/uber
# 4 rows affected.
# [('Lyft', Decimal('18.43')),
#  ('Uber', Decimal('11.83')),
#  ('Via', Decimal('9.03')),
#  ('Juno', Decimal('8.25'))]

# %% [markdown]
# ### Market Share

# %%
# %%sql
# SELECT platform,
# ROUND(
#     (100 * COUNT(*) / (SELECT COUNT(*) FROM main))::numeric
# , 2) market_share
# FROM main
# GROUP BY platform
# ORDER BY COUNT(*) DESC
# Out:
#  * postgresql://root:***@localhost:5432/uber
# 4 rows affected.
# [('Uber', Decimal('68.00')),
#  ('Lyft', Decimal('23.00')),
#  ('Via', Decimal('4.00')),
#  ('Juno', Decimal('3.00'))]

# %% [markdown]
# ### Pay per Mile
# - Using the view, I compute the average pay per mile for each platform
# - Juno and Uber pay the highest
# - Interestingly, Via pays much lower

# %%
# %%sql
# SELECT
# platform,
# ROUND(
#     AVG(driver_pay / trip_miles)::numeric
#     ,2) pay_per_mile
# FROM aux
# WHERE trip_miles > 0.00
# GROUP BY platform
# ORDER BY AVG(driver_pay / trip_miles) DESC
# Out:
#  * postgresql://root:***@localhost:5432/uber
# 4 rows affected.
# [('Juno', Decimal('4.91')),
#  ('Uber', Decimal('4.42')),
#  ('Lyft', Decimal('3.66')),
#  ('Via', Decimal('0.23'))]

# %% [markdown]
# ### Pay per Mile - With Tips
# - It's possible that the lower pay of Lyft drivers is compensated by their higher tip rate
# - To examine this, I now include tips when computing driver pay
# - Naturally, including tips increases driver pay per mile, but doesn't remove the advantage that uber has over lyft

# %%
# %%sql
# SELECT
# platform,
# ROUND(
#     AVG((driver_pay + tips) / trip_miles)::numeric
#     ,2) pay_per_mile
# FROM aux
# WHERE trip_miles > 0.00
# GROUP BY platform
# ORDER BY AVG(driver_pay / trip_miles) DESC
# Out:
#  * postgresql://root:***@localhost:5432/uber
# 4 rows affected.
# [('Juno', Decimal('5.01')),
#  ('Uber', Decimal('4.59')),
#  ('Lyft', Decimal('3.89')),
#  ('Via', Decimal('0.31'))]

# %% [markdown]
# ### Pay per Minute
# - Using the view, I compute average pay per minute for each platform
# - Juno and Uber again pay the highest rate, with Lyft paying a lower rate

# %%
# %%sql
# SELECT
# platform,
# ROUND(
#     AVG(driver_pay / trip_minutes)::numeric
#     ,2) pay_per_minute
# FROM aux
# WHERE trip_minutes > 0.00
# GROUP BY platform
# ORDER BY AVG(driver_pay / trip_minutes) DESC;
# Out:
#  * postgresql://root:***@localhost:5432/uber
# 4 rows affected.
# [('Juno', Decimal('1.00')),
#  ('Uber', Decimal('0.90')),
#  ('Lyft', Decimal('0.67')),
#  ('Via', Decimal('0.05'))]

# %% [markdown]
# ## Time of Day
# - We can see the lowest pay per mile is at late night
# - In contrast, late night pays the highest *per minute*
# - Tips are more likely at mid-day at least likely late at night

# %%
# %%sql
# SELECT
# pickup_hour,
# ROUND(
#     AVG(driver_pay_per_mile)::numeric
#     , 2) "Average Pay per Mile"
# FROM main
# GROUP BY pickup_hour
# ORDER BY pickup_hour ASC;
# Out:
#  * postgresql://root:***@localhost:5432/uber
# 24 rows affected.
# [(0, Decimal('3.57')),
#  (1, Decimal('3.31')),
#  (2, Decimal('3.26')),
#  (3, Decimal('3.11')),
#  (4, Decimal('3.45')),
#  (5, Decimal('3.89')),
#  (6, Decimal('3.09')),
#  (7, Decimal('3.49')),
#  (8, Decimal('4.17')),
#  (9, Decimal('4.09')),
#  (10, Decimal('4.22')),
#  (11, Decimal('4.19')),
#  (12, Decimal('4.08')),
#  (13, Decimal('4.19')),
#  (14, Decimal('4.15')),
#  (15, Decimal('4.27')),
#  (16, Decimal('4.97')),
#  (17, Decimal('4.29')),
#  (18, Decimal('4.77')),
#  (19, Decimal('4.19')),
#  (20, Decimal('3.96')),
#  (21, Decimal('4.81')),
#  (22, Decimal('3.76')),
#  (23, Decimal('3.57'))]

# %%
# %%sql
# SELECT
# pickup_hour,
# ROUND(
#     AVG(driver_pay_per_minute)::numeric
#     , 2) "Average Pay per Minute"
# FROM main
# GROUP BY pickup_hour
# ORDER BY pickup_hour ASC;
# Out:
#  * postgresql://root:***@localhost:5432/uber
# 24 rows affected.
# [(0, Decimal('0.82')),
#  (1, Decimal('0.81')),
#  (2, Decimal('0.87')),
#  (3, Decimal('0.87')),
#  (4, Decimal('0.92')),
#  (5, Decimal('1.02')),
#  (6, Decimal('0.85')),
#  (7, Decimal('0.77')),
#  (8, Decimal('0.75')),
#  (9, Decimal('0.75')),
#  (10, Decimal('0.77')),
#  (11, Decimal('0.76')),
#  (12, Decimal('0.76')),
#  (13, Decimal('0.75')),
#  (14, Decimal('0.74')),
#  (15, Decimal('0.72')),
#  (16, Decimal('0.73')),
#  (17, Decimal('0.73')),
#  (18, Decimal('0.75')),
#  (19, Decimal('0.77')),
#  (20, Decimal('0.77')),
#  (21, Decimal('0.80')),
#  (22, Decimal('0.80')),
#  (23, Decimal('0.81'))]

# %%
# %%sql
# SELECT
# pickup_hour,
# ROUND(
#     100*AVG(has_tips)::numeric
#     , 2) "Average Pay per Minute"
# FROM main
# GROUP BY pickup_hour
# ORDER BY pickup_hour ASC;
# Out:
#  * postgresql://root:***@localhost:5432/uber
# 24 rows affected.
# [(0, Decimal('11.23')),
#  (1, Decimal('9.89')),
#  (2, Decimal('10.89')),
#  (3, Decimal('10.01')),
#  (4, Decimal('10.70')),
#  (5, Decimal('14.59')),
#  (6, Decimal('12.23')),
#  (7, Decimal('10.96')),
#  (8, Decimal('12.57')),
#  (9, Decimal('13.91')),
#  (10, Decimal('14.08')),
#  (11, Decimal('15.48')),
#  (12, Decimal('14.90')),
#  (13, Decimal('15.03')),
#  (14, Decimal('14.26')),
#  (15, Decimal('13.54')),
#  (16, Decimal('13.46')),
#  (17, Decimal('14.87')),
#  (18, Decimal('14.40')),
#  (19, Decimal('12.65')),
#  (20, Decimal('12.60')),
#  (21, Decimal('12.84')),
#  (22, Decimal('12.16')),
#  (23, Decimal('11.92'))]
